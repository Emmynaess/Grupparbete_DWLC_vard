# %% [markdown]
# # EDA on healthcare jobs from API
#
# ## Quick look into the data

# %%
import requests
import json
import pprint

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"

result = requests.get(url_for_search)

pprint.pprint(result.json())
# Out:
# {'freetext_concepts': {},
#  'hits': [{'access': None,
#            'access_to_own_car': False,
#            'application_contacts': [{'contact_type': 'Verksamhetsansvarig',
#                                      'description': None,
#                                      'email': 'jobb@optimalassistans.org',
#                                      'name': 'Monika Y Wassberg',
#                                      'telephone': None}],
#            'application_deadline': '2024-10-04T23:59:59',
#            'application_details': {'email': 'jobb@optimalassistans.org',
#                                    'information': None,
#                                    'other': None,
#                                    'reference': None,
#                                    'url': 'http://www.optimalassistans.org/jobbansokan',
#                                    'via_af': False},
#            'description': {'company_information': None,
#                            'conditions': None,
# ...

# %%
for i in result.json()['hits']:
    print(i)
# Out:
# {'relevance': 0.0, 'id': '29073723', 'external_id': '46-556035-4309-wb-279607', 'original_id': None, 'label': '[]', 'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29073723', 'logo_url': 'https://www.arbetsformedlingen.se/rest/arbetsgivare/rest/af/v3/organisation/5560354309/logotyper/logo.png', 'headline': 'Pysslingen Förskolor söker timvikarier till Kungsholmen', 'application_deadline': '2024-10-03T23:59:59', 'number_of_vacancies': 3, 'description': {'text': 'Just nu söker vi timvikarier till våra fina förskolor på Kungsholmen. Tycker du om att ha roligt på jobbet, gillar att arbeta flexibelt och är intresserad av att arbeta med barn i åldrarna 1-5? Tveka inte att skicka en ansökan till oss! 🌟\n\nOm rollen\n\nTjänsten som timvikarie gäller förskolorna Nallebjörnen, Tranan, Brovaktaren och Sjötullen. Det finns goda förbindelser till samtliga förskolor, vilket ger dig möjlighet till fler arbetstimmar och ett mer varierat arbete!\n\nSom timvikarie hos oss på Pyssling
# ...

# %%
def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")

# create a loop to loop through the different positions we are looking for
positions = ['sjuksköterska', 'läkare', 'teraupet', 'sjukgymnast', 'psykolog', 'undersköterska', 'barnmorska', 'vårdbiträden']


for i in positions:
    query = i
    example_search_return_number_of_hits(query)
    example_search_loop_through_hits(query)
# Out:
# Number of hits = 2015
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska , REGION JÖNKÖPINGS LÄN
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, Luleå kommun
# Sjuksköterska, Arboga kommun
# Sjuksköterska, Capio Sverige AB
# Sjuksköterska, Capio Sverige AB
# Sjuksköterska, Randstad AB
# Sjuksköterska, Capio Sverige AB
# Sjuksköterska, Attendo Sverige AB
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, Humana AB
# Sjuksköterska, Capio Sverige AB
# Sjuksköterska, Humana AB
# Sjuksköterska, REGION UPPSALA
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, Aleris Sjukvård AB
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, Capio Sverige AB
# Sjuksköterska, REGION JÖNKÖPINGS LÄN
# Sjuksköterska, Doktorse Nordic AB
# Sjuksköterska, REGION UPPSALA
# Sjuksköterska, Stockholms kommun
# Sjuksköterska, Kosmetisk Kirurgi & Cosmetic Surgery LL Medical
# Sjuksköterska, Essem Care AB
# ...
